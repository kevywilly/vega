# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mag_x = 60
mag_y = 20
mag_z = 60
step_size = 1

# %%
x0 = np.sin(np.radians(np.arange(0,90, step_size))) * mag_x
x0 = np.sin(np.radians(np.arange(0,90, step_size))) * mag_x
x1 = np.sin(np.radians(np.arange(180,180+45, step_size))) * mag_x
x2_0 = x1_0
x3_0 = x1_0

x0_1 = np.sin(np.radians(np.arange(0,90, step_size))) * mag_x
x1_0 = np.sin(np.radians(np.arange(180,180+45, step_size))) * mag_x
x2_0 = x1_0
x3_0 = x1_0

plt.plot(x0_0, label = "x0")
plt.plot(x1_0, label = "x1")
plt.plot(x2_0, label = "x2")
plt.plot(x3_0, label = "x3")
plt.legend()
plt.show()
