# %%
from src.motion.gaits.tiger_run import TigerRun
# from src.motion.gaits.trot import Trot

# %%
gait1 = TigerRun(stride=70, clearance=70, step_size=10)

gait1.plotit()
# Out:
# leg 1
# leg 2
# leg 3
# leg 4
