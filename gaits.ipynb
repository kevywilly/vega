# %%
from src.motion.gaits.jump import Jump
from src.motion.gaits.trot import Trot

# %%
gait1 = Jump(stride=40, clearance=60, step_size=20)

gait1.plotit()
# Out:
# leg 1
# leg 2

# %%
from src.motion.gaits.trot import Trot

gait = Trot(stride=0, clearance=0, step_size=25)
gait.steps2.shape
# Out:
# (12, 3)
